# %%
# Manas Pratim Biswas
# 002011001025

# %%
import collections
import copy
import numpy as np
import sys

# %%
with open('initialState.txt') as f:
    lines = f.readlines()
    
initialState = []
finalState = []

for line in lines:
    row = [int(i) for i in line.split()]
    initialState.append(row)
    
with open('finalState.txt') as g:
    lines = g.readlines()
    
for line in lines:
    row = [int(i) for i in line.split()]
    finalState.append(row)

# %%
def printLine():
    print("----------------------------------\n")

# %%
class Node:
    def __init__(self, state, parent, action):
        self.state = state
        self.parent = parent
        self.action = action


class StackFrontier:
    def __init__(self):
        self.frontier = []

    def add(self, node):
        self.frontier.append(node)

    def contains_state(self, state):
        return any((node.state[0] == state[0]).all() for node in self.frontier)

    def empty(self):
        return len(self.frontier) == 0

    def remove(self):
        if self.empty():
            raise Exception("Empty Frontier")
        else:
            node = self.frontier[-1]
            self.frontier = self.frontier[:-1]
            return node


class QueueFrontier(StackFrontier):
    def remove(self):
        if self.empty():
            raise Exception("Empty Frontier")
        else:
            node = self.frontier[0]
            self.frontier = self.frontier[1:]
            return node


class Puzzle:
    def __init__(self, start, startIndex, goal, goalIndex):
        self.start = [start, startIndex]
        self.goal = [goal, goalIndex] 
        self.solution = None

    def neighbors(self, state):
        mat, (row, col) = state
        results = []

        if row > 0:
            mat1 = np.copy(mat)
            mat1[row][col] = mat1[row - 1][col]
            mat1[row - 1][col] = 0
            results.append(('UP', [mat1, (row - 1, col)]))
        if col > 0:
            mat1 = np.copy(mat)
            mat1[row][col] = mat1[row][col - 1]
            mat1[row][col - 1] = 0
            results.append(('LEFT', [mat1, (row, col - 1)]))
        if row < 2:
            mat1 = np.copy(mat)
            mat1[row][col] = mat1[row + 1][col]
            mat1[row + 1][col] = 0
            results.append(('DOWN', [mat1, (row + 1, col)]))
        if col < 2:
            mat1 = np.copy(mat)
            mat1[row][col] = mat1[row][col + 1]
            mat1[row][col + 1] = 0
            results.append(('RIGHT', [mat1, (row, col + 1)]))

        return results

    def print(self):
        solution = self.solution if self.solution is not None else None
        print("Initial State:-\n", self.start[0], "\n")
        print("Final State:-\n",  self.goal[0], "\n")
        print("\nStates Explored: ", self.num_explored, "\n")
        print("Solution:-\n ")
        for action, cell in zip(solution[0], solution[1]):
            print("Move:- ", action, "\n", cell[0], "\n")
        print("The Final State is Reached!")

    def does_not_contain_state(self, state):
        for st in self.explored:
            if (st[0] == state[0]).all():
                return False
        return True

    def solve(self):
        self.num_explored = 0

        start = Node(state=self.start, parent=None, action=None)
        frontier = QueueFrontier()
        frontier.add(start)

        self.explored = [] 

        while True:
            if frontier.empty():
                raise Exception("No Solution!")

            node = frontier.remove()
            self.num_explored += 1

            if (node.state[0] == self.goal[0]).all():
                actions = []
                cells = []
                while node.parent is not None:
                    actions.append(node.action)
                    cells.append(node.state)
                    node = node.parent
                    actions.reverse()
                cells.reverse()
                self.solution = (actions,  cells)
                return

            self.explored.append(node.state)

            for action, state in self.neighbors(node.state):
                if not frontier.contains_state(state) and self.does_not_contain_state(state):
                    child = Node(state=state, parent=node, action=action)
                    frontier.add(child)

# %%
def generateAllStates(board) -> int:
        m = len(board)
        n = len(board[0])        
        moves = 0
        q = collections.deque([]) 
        visited = set()
       
        
        def getNeighbours(i,j,board):
            ans = []
            for x,y in [(1,0),(0,1),(-1,0),(0,-1)]:
                nx = i+x
                ny = j+y        
                
                if nx < 0 or nx >= m or ny < 0 or ny >= n:
                    continue
                board[i][j],board[nx][ny] = board[nx][ny], board[i][j]
                ans.append((nx,ny,copy.deepcopy(board)))
                board[nx][ny],board[i][j] = board[i][j],board[nx][ny]  
            return ans          
        
        for i in range(m):
            for j in range(n):
                if board[i][j]==0:
                    q.append((i,j,board.copy()))
        ans = -1
        temporaryBoard=[]
        while q:
            print("Current Level :- ",moves+1)
            print("All Possible States :- ")
            printLine()
            for _ in range(len(q)):
                curri,currj,currBoard=q.popleft()
                visited.add(str(currBoard))
                
                if currBoard==finalState: 
                    return moves
                
                neighbours = getNeighbours(curri,currj,currBoard)
               
                
                for x,y,board in neighbours:
                    if str(board) not in visited:
                        npBoard = np.array(board)
                        print(npBoard)
                        print()
                        temporaryBoard.append(board)
                        q.append((x,y,board))
                        
            moves += 1
        
        return -1;

# %%
initialGrid = np.array(initialState)
finalGrid = np.array(finalState)
initialX = -1
initialY = -1
finalX = -1
finalY = -1

# %%
for i in range(3):
    for j in range(3):
        if(initialState[i][j]==0):
            initialX = i
            initialY = j
            
for i in range(3):
    for j in range(3):
        if(finalState[i][j]==0):
            finalX = i
            finalY = j

# %%
initialIndex = (initialX,initialY)
finalIndex = (finalX,finalY)

# %%
minimumSteps = generateAllStates(initialState)
# Out:
# Current Level :-  1
# All Possible States :-
# ----------------------------------
#
# [[1 2 3]
#  [8 6 4]
#  [7 0 5]]
#
# [[1 2 3]
#  [8 4 0]
#  [7 6 5]]
#
# [[1 0 3]
#  [8 2 4]
#  [7 6 5]]
#
# [[1 2 3]
#  [0 8 4]
#  [7 6 5]]
#
# Current Level :-  2
# All Possible States :-
# ----------------------------------
#
# [[1 2 3]
#  [8 6 4]
#  [7 5 0]]
#
# [[1 2 3]
#  [8 6 4]
#  [0 7 5]]
#
# [[1 2 3]
#  [8 4 5]
#  [7 6 0]]
#
# [[1 2 0]
#  [8 4 3]
#  [7 6 5]]
#
# [[1 3 0]
#  [8 2 4]
#  [7 6 5]]
#
# [[0 1 3]
#  [8 2 4]
#  [7 6 5]]
#
# [[1 2 3]
#  [7 8 4]
#  [0 6 5]]
#
# [[0 2 3]
#  [1 8 4]
#  [7 6 5]]
#
# Current Level :-  3
# All Possible States :-
# ----------------------------------
#
# [[1 2 3]
#  [8 6 0]
#  [7 5 4]]
#
# [[1 2 3]
#  [0 6 4]
#  [8 7 5]]
#
# [[1 2 3]
#  [8 4 5]
#  [7 0 6]]
#
# [[1 0 2]
#  [8 4 3]
#  [7 6 5]]
#
# [[1 3 4]
#  [8 2 0]
#  [7 6 5]]
#
# [[8 1 3]
#  [0 2 4]
#  [7 6 5]]
#
# [[1 2 3]
#  [7 8 4]
#  [6 0 5]]
#
# [[2 0 3]
#  [1 8 4]
#  [7 6 5]]
#
# Current Level :-  4
# All Possible States :-
# ----------------------------------
#
# [[1 2 0]
#  [8 6 3]
#  [7 5 4]]
#
# [[1 2 3]
#  [8 0 6]
#  [7 5 4]]
#
# [[1 2 3]
#  [6 0 4]
#  [8 7 5]]
#
# [[0 2 3]
#  [1 6 4]
#  [8 7 5]]
#
# [[1 2 3]
#  [8 0 5]
#  [7 4 6]]
#
# [[1 2 3]
#  [8 4 5]
#  [0 7 6]]
#
# [[1 4 2]
#  [8 0 3]
#  [7 6 5]]
#
# [[0 1 2]
#  [8 4 3]
#  [7 6 5]]
#
# [[1 3 4]
#  [8 2 5]
#  [7 6 0]]
#
# [[1 3 4]
#  [8 0 2]
#  [7 6 5]]
#
# [[8 1 3]
#  [7 2 4]
#  [0 6 5]]
#
# [[8 1 3]
#  [2 0 4]
#  [7 6 5]]
#
# [[1 2 3]
#  [7 8 4]
#  [6 5 0]]
#
# [[1 2 3]
#  [7 0 4]
#  [6 8 5]]
#
# [[2 8 3]
#  [1 0 4]
#  [7 6 5]]
#
# [[2 3 0]
#  [1 8 4]
#  [7 6 5]]
#
# Current Level :-  5
# All Possible States :-
# ----------------------------------
#
# [[1 0 2]
#  [8 6 3]
#  [7 5 4]]
#
# [[1 2 3]
#  [8 5 6]
#  [7 0 4]]
#
# [[1 0 3]
#  [8 2 6]
#  [7 5 4]]
#
# [[1 2 3]
#  [0 8 6]
#  [7 5 4]]
#
# [[1 2 3]
#  [6 7 4]
#  [8 0 5]]
#
# [[1 2 3]
#  [6 4 0]
#  [8 7 5]]
#
# [[1 0 3]
#  [6 2 4]
#  [8 7 5]]
#
# [[2 0 3]
#  [1 6 4]
#  [8 7 5]]
#
# [[1 2 3]
#  [8 5 0]
#  [7 4 6]]
#
# [[1 0 3]
#  [8 2 5]
#  [7 4 6]]
#
# [[1 2 3]
#  [0 8 5]
#  [7 4 6]]
#
# [[1 2 3]
#  [0 4 5]
#  [8 7 6]]
#
# [[1 4 2]
#  [8 6 3]
#  [7 0 5]]
#
# [[1 4 2]
#  [8 3 0]
#  [7 6 5]]
#
# [[1 4 2]
#  [0 8 3]
#  [7 6 5]]
#
# [[8 1 2]
#  [0 4 3]
#  [7 6 5]]
#
# [[1 3 4]
#  [8 2 5]
#  [7 0 6]]
#
# [[1 3 4]
#  [8 6 2]
#  [7 0 5]]
#
# [[1 0 4]
#  [8 3 2]
#  [7 6 5]]
#
# [[1 3 4]
#  [0 8 2]
#  [7 6 5]]
#
# [[8 1 3]
#  [7 2 4]
#  [6 0 5]]
#
# [[8 1 3]
#  [2 6 4]
#  [7 0 5]]
#
# [[8 1 3]
#  [2 4 0]
#  [7 6 5]]
#
# [[8 0 3]
#  [2 1 4]
#  [7 6 5]]
#
# [[1 2 3]
#  [7 8 0]
#  [6 5 4]]
#
# [[1 2 3]
#  [7 4 0]
#  [6 8 5]]
#
# [[1 0 3]
#  [7 2 4]
#  [6 8 5]]
#
# [[1 2 3]
#  [0 7 4]
#  [6 8 5]]
#
# [[2 8 3]
#  [1 6 4]
#  [7 0 5]]
#
# [[2 8 3]
#  [1 4 0]
#  [7 6 5]]
#
# [[2 8 3]
#  [0 1 4]
#  [7 6 5]]
#
# [[2 3 4]
#  [1 8 0]
#  [7 6 5]]
#
# Current Level :-  6
# All Possible States :-
# ----------------------------------
#
# [[1 6 2]
#  [8 0 3]
#  [7 5 4]]
#
# [[0 1 2]
#  [8 6 3]
#  [7 5 4]]
#
# [[1 2 3]
#  [8 5 6]
#  [7 4 0]]
#
# [[1 2 3]
#  [8 5 6]
#  [0 7 4]]
#
# [[1 3 0]
#  [8 2 6]
#  [7 5 4]]
#
# [[0 1 3]
#  [8 2 6]
#  [7 5 4]]
#
# [[1 2 3]
#  [7 8 6]
#  [0 5 4]]
#
# [[0 2 3]
#  [1 8 6]
#  [7 5 4]]
#
# [[1 2 3]
#  [6 7 4]
#  [8 5 0]]
#
# [[1 2 3]
#  [6 7 4]
#  [0 8 5]]
#
# [[1 2 3]
#  [6 4 5]
#  [8 7 0]]
#
# [[1 2 0]
#  [6 4 3]
#  [8 7 5]]
#
# [[1 3 0]
#  [6 2 4]
#  [8 7 5]]
#
# [[0 1 3]
#  [6 2 4]
#  [8 7 5]]
#
# [[2 6 3]
#  [1 0 4]
#  [8 7 5]]
#
# [[2 3 0]
#  [1 6 4]
#  [8 7 5]]
#
# [[1 2 3]
#  [8 5 6]
#  [7 4 0]]
#
# [[1 2 0]
#  [8 5 3]
#  [7 4 6]]
#
# [[1 3 0]
#  [8 2 5]
#  [7 4 6]]
#
# [[0 1 3]
#  [8 2 5]
#  [7 4 6]]
#
# [[1 2 3]
#  [7 8 5]
#  [0 4 6]]
#
# [[0 2 3]
#  [1 8 5]
#  [7 4 6]]
#
# [[1 2 3]
#  [4 0 5]
#  [8 7 6]]
#
# [[0 2 3]
#  [1 4 5]
#  [8 7 6]]
#
# [[1 4 2]
#  [8 6 3]
#  [7 5 0]]
#
# [[1 4 2]
#  [8 6 3]
#  [0 7 5]]
#
# [[1 4 2]
#  [8 3 5]
#  [7 6 0]]
#
# [[1 4 0]
#  [8 3 2]
#  [7 6 5]]
#
# [[1 4 2]
#  [7 8 3]
#  [0 6 5]]
#
# [[0 4 2]
#  [1 8 3]
#  [7 6 5]]
#
# [[8 1 2]
#  [7 4 3]
#  [0 6 5]]
#
# [[8 1 2]
#  [4 0 3]
#  [7 6 5]]
#
# [[1 3 4]
#  [8 0 5]
#  [7 2 6]]
#
# [[1 3 4]
#  [8 2 5]
#  [0 7 6]]
#
# [[1 3 4]
#  [8 6 2]
#  [7 5 0]]
#
# [[1 3 4]
#  [8 6 2]
#  [0 7 5]]
#
# [[1 4 0]
#  [8 3 2]
#  [7 6 5]]
#
# [[0 1 4]
#  [8 3 2]
#  [7 6 5]]
#
# [[1 3 4]
#  [7 8 2]
#  [0 6 5]]
#
# [[0 3 4]
#  [1 8 2]
#  [7 6 5]]
#
# [[8 1 3]
#  [7 2 4]
#  [6 5 0]]
#
# [[8 1 3]
#  [7 0 4]
#  [6 2 5]]
#
# [[8 1 3]
#  [2 6 4]
#  [7 5 0]]
#
# [[8 1 3]
#  [2 6 4]
#  [0 7 5]]
#
# [[8 1 3]
#  [2 4 5]
#  [7 6 0]]
#
# [[8 1 0]
#  [2 4 3]
#  [7 6 5]]
#
# [[8 3 0]
#  [2 1 4]
#  [7 6 5]]
#
# [[0 8 3]
#  [2 1 4]
#  [7 6 5]]
#
# [[1 2 0]
#  [7 8 3]
#  [6 5 4]]
#
# [[1 2 3]
#  [7 0 8]
#  [6 5 4]]
#
# [[1 2 3]
#  [7 4 5]
#  [6 8 0]]
#
# [[1 2 0]
#  [7 4 3]
#  [6 8 5]]
#
# [[1 3 0]
#  [7 2 4]
#  [6 8 5]]
#
# [[0 1 3]
#  [7 2 4]
#  [6 8 5]]
#
# [[1 2 3]
#  [6 7 4]
#  [0 8 5]]
#
# [[0 2 3]
#  [1 7 4]
#  [6 8 5]]
#
# [[2 8 3]
#  [1 6 4]
#  [7 5 0]]
#
# [[2 8 3]
#  [1 6 4]
#  [0 7 5]]
#
# [[2 8 3]
#  [1 4 5]
#  [7 6 0]]
#
# [[2 8 0]
#  [1 4 3]
#  [7 6 5]]
#
# [[2 8 3]
#  [7 1 4]
#  [0 6 5]]
#
# [[0 8 3]
#  [2 1 4]
#  [7 6 5]]
#
# [[2 3 4]
#  [1 8 5]
#  [7 6 0]]
#
# [[2 3 4]
#  [1 0 8]
#  [7 6 5]]
#
# Current Level :-  7
# All Possible States :-
# ----------------------------------
#
# [[1 6 2]
#  [8 5 3]
#  [7 0 4]]
#
# [[1 6 2]
#  [8 3 0]
#  [7 5 4]]
#
# [[1 6 2]
#  [0 8 3]
#  [7 5 4]]
#
# [[8 1 2]
#  [0 6 3]
#  [7 5 4]]
#
# [[1 2 3]
#  [0 5 6]
#  [8 7 4]]
#
# [[1 3 6]
#  [8 2 0]
#  [7 5 4]]
#
# [[8 1 3]
#  [0 2 6]
#  [7 5 4]]
#
# [[1 2 3]
#  [7 8 6]
#  [5 0 4]]
#
# [[2 0 3]
#  [1 8 6]
#  [7 5 4]]
#
# [[1 2 3]
#  [6 7 0]
#  [8 5 4]]
#
# [[1 2 3]
#  [6 4 5]
#  [8 0 7]]
#
# [[1 0 2]
#  [6 4 3]
#  [8 7 5]]
#
# [[1 3 4]
#  [6 2 0]
#  [8 7 5]]
#
# [[6 1 3]
#  [0 2 4]
#  [8 7 5]]
#
# [[2 6 3]
#  [1 7 4]
#  [8 0 5]]
#
# [[2 6 3]
#  [1 4 0]
#  [8 7 5]]
#
# [[2 6 3]
#  [0 1 4]
#  [8 7 5]]
#
# [[2 3 4]
#  [1 6 0]
#  [8 7 5]]
#
# [[1 0 2]
#  [8 5 3]
#  [7 4 6]]
#
# [[1 3 5]
#  [8 2 0]
#  [7 4 6]]
#
# [[8 1 3]
#  [0 2 5]
#  [7 4 6]]
#
# [[1 2 3]
#  [7 8 5]
#  [4 0 6]]
#
# [[2 0 3]
#  [1 8 5]
#  [7 4 6]]
#
# [[1 2 3]
#  [4 7 5]
#  [8 0 6]]
#
# [[1 2 3]
#  [4 5 0]
#  [8 7 6]]
#
# [[1 0 3]
#  [4 2 5]
#  [8 7 6]]
#
# [[2 0 3]
#  [1 4 5]
#  [8 7 6]]
#
# [[1 4 2]
#  [8 6 0]
#  [7 5 3]]
#
# [[1 4 2]
#  [0 6 3]
#  [8 7 5]]
#
# [[1 4 2]
#  [8 3 5]
#  [7 0 6]]
#
# [[1 4 2]
#  [7 8 3]
#  [6 0 5]]
#
# [[4 0 2]
#  [1 8 3]
#  [7 6 5]]
#
# [[8 1 2]
#  [7 4 3]
#  [6 0 5]]
#
# [[8 1 2]
#  [4 6 3]
#  [7 0 5]]
#
# [[8 1 2]
#  [4 3 0]
#  [7 6 5]]
#
# [[8 0 2]
#  [4 1 3]
#  [7 6 5]]
#
# [[1 3 4]
#  [8 5 0]
#  [7 2 6]]
#
# [[1 0 4]
#  [8 3 5]
#  [7 2 6]]
#
# [[1 3 4]
#  [0 8 5]
#  [7 2 6]]
#
# [[1 3 4]
#  [0 2 5]
#  [8 7 6]]
#
# [[1 3 4]
#  [8 6 0]
#  [7 5 2]]
#
# [[1 3 4]
#  [0 6 2]
#  [8 7 5]]
#
# [[8 1 4]
#  [0 3 2]
#  [7 6 5]]
#
# [[1 3 4]
#  [7 8 2]
#  [6 0 5]]
#
# [[3 0 4]
#  [1 8 2]
#  [7 6 5]]
#
# [[8 1 3]
#  [7 2 0]
#  [6 5 4]]
#
# [[8 1 3]
#  [7 4 0]
#  [6 2 5]]
#
# [[8 0 3]
#  [7 1 4]
#  [6 2 5]]
#
# [[8 1 3]
#  [0 7 4]
#  [6 2 5]]
#
# [[8 1 3]
#  [2 6 0]
#  [7 5 4]]
#
# [[8 1 3]
#  [0 6 4]
#  [2 7 5]]
#
# [[8 1 3]
#  [2 4 5]
#  [7 0 6]]
#
# [[8 0 1]
#  [2 4 3]
#  [7 6 5]]
#
# [[8 3 4]
#  [2 1 0]
#  [7 6 5]]
#
# [[1 0 2]
#  [7 8 3]
#  [6 5 4]]
#
# [[1 2 3]
#  [7 5 8]
#  [6 0 4]]
#
# [[1 0 3]
#  [7 2 8]
#  [6 5 4]]
#
# [[1 2 3]
#  [0 7 8]
#  [6 5 4]]
#
# [[1 2 3]
#  [7 4 5]
#  [6 0 8]]
#
# [[1 0 2]
#  [7 4 3]
#  [6 8 5]]
#
# [[1 3 4]
#  [7 2 0]
#  [6 8 5]]
#
# [[7 1 3]
#  [0 2 4]
#  [6 8 5]]
#
# [[2 0 3]
#  [1 7 4]
#  [6 8 5]]
#
# [[2 8 3]
#  [1 6 0]
#  [7 5 4]]
#
# [[2 8 3]
#  [0 6 4]
#  [1 7 5]]
#
# [[2 8 3]
#  [1 4 5]
#  [7 0 6]]
#
# [[2 0 8]
#  [1 4 3]
#  [7 6 5]]
#
# [[2 8 3]
#  [7 1 4]
#  [6 0 5]]
#
# [[2 3 4]
#  [1 8 5]
#  [7 0 6]]
#
# [[2 3 4]
#  [1 6 8]
#  [7 0 5]]
#
# [[2 0 4]
#  [1 3 8]
#  [7 6 5]]
#
# [[2 3 4]
#  [0 1 8]
#  [7 6 5]]
#
# Current Level :-  8
# All Possible States :-
# ----------------------------------
#
# [[1 6 2]
#  [8 5 3]
#  [7 4 0]]
#
# [[1 6 2]
#  [8 5 3]
#  [0 7 4]]
#
# [[1 6 2]
#  [8 3 4]
#  [7 5 0]]
#
# [[1 6 0]
#  [8 3 2]
#  [7 5 4]]
#
# [[1 6 2]
#  [7 8 3]
#  [0 5 4]]
#
# [[0 6 2]
#  [1 8 3]
#  [7 5 4]]
#
# [[8 1 2]
#  [7 6 3]
#  [0 5 4]]
#
# [[8 1 2]
#  [6 0 3]
#  [7 5 4]]
#
# [[1 2 3]
#  [5 0 6]
#  [8 7 4]]
#
# [[0 2 3]
#  [1 5 6]
#  [8 7 4]]
#
# [[1 3 6]
#  [8 2 4]
#  [7 5 0]]
#
# [[1 3 6]
#  [8 0 2]
#  [7 5 4]]
#
# [[8 1 3]
#  [7 2 6]
#  [0 5 4]]
#
# [[8 1 3]
#  [2 0 6]
#  [7 5 4]]
#
# [[1 2 3]
#  [7 8 6]
#  [5 4 0]]
#
# [[1 2 3]
#  [7 0 6]
#  [5 8 4]]
#
# [[2 8 3]
#  [1 0 6]
#  [7 5 4]]
#
# [[2 3 0]
#  [1 8 6]
#  [7 5 4]]
#
# [[1 2 0]
#  [6 7 3]
#  [8 5 4]]
#
# [[1 2 3]
#  [6 0 7]
#  [8 5 4]]
#
# [[1 2 3]
#  [6 0 5]
#  [8 4 7]]
#
# [[1 2 3]
#  [6 4 5]
#  [0 8 7]]
#
# [[1 4 2]
#  [6 0 3]
#  [8 7 5]]
#
# [[0 1 2]
#  [6 4 3]
#  [8 7 5]]
#
# [[1 3 4]
#  [6 2 5]
#  [8 7 0]]
#
# [[1 3 4]
#  [6 0 2]
#  [8 7 5]]
#
# [[6 1 3]
#  [8 2 4]
#  [0 7 5]]
#
# [[6 1 3]
#  [2 0 4]
#  [8 7 5]]
#
# [[2 6 3]
#  [1 7 4]
#  [8 5 0]]
#
# [[2 6 3]
#  [1 7 4]
#  [0 8 5]]
#
# [[2 6 3]
#  [1 4 5]
#  [8 7 0]]
#
# [[2 6 0]
#  [1 4 3]
#  [8 7 5]]
#
# [[2 6 3]
#  [8 1 4]
#  [0 7 5]]
#
# [[0 6 3]
#  [2 1 4]
#  [8 7 5]]
#
# [[2 3 4]
#  [1 6 5]
#  [8 7 0]]
#
# [[2 3 4]
#  [1 0 6]
#  [8 7 5]]
#
# [[1 5 2]
#  [8 0 3]
#  [7 4 6]]
#
# [[0 1 2]
#  [8 5 3]
#  [7 4 6]]
#
# [[1 3 5]
#  [8 2 6]
#  [7 4 0]]
#
# [[1 3 5]
#  [8 0 2]
#  [7 4 6]]
#
# [[8 1 3]
#  [7 2 5]
#  [0 4 6]]
#
# [[8 1 3]
#  [2 0 5]
#  [7 4 6]]
#
# [[1 2 3]
#  [7 8 5]
#  [4 6 0]]
#
# [[1 2 3]
#  [7 0 5]
#  [4 8 6]]
#
# [[2 8 3]
#  [1 0 5]
#  [7 4 6]]
#
# [[2 3 0]
#  [1 8 5]
#  [7 4 6]]
#
# [[1 2 3]
#  [4 7 5]
#  [8 6 0]]
#
# [[1 2 3]
#  [4 7 5]
#  [0 8 6]]
#
# [[1 2 3]
#  [4 5 6]
#  [8 7 0]]
#
# [[1 2 0]
#  [4 5 3]
#  [8 7 6]]
#
# [[1 3 0]
#  [4 2 5]
#  [8 7 6]]
#
# [[0 1 3]
#  [4 2 5]
#  [8 7 6]]
#
# [[2 4 3]
#  [1 0 5]
#  [8 7 6]]
#
# [[2 3 0]
#  [1 4 5]
#  [8 7 6]]
#
# [[1 4 0]
#  [8 6 2]
#  [7 5 3]]
#
# [[1 4 2]
#  [8 0 6]
#  [7 5 3]]
#
# [[1 4 2]
#  [6 0 3]
#  [8 7 5]]
#
# [[0 4 2]
#  [1 6 3]
#  [8 7 5]]
#
# [[1 4 2]
#  [8 0 5]
#  [7 3 6]]
#
# [[1 4 2]
#  [8 3 5]
#  [0 7 6]]
#
# [[1 4 2]
#  [7 8 3]
#  [6 5 0]]
#
# [[1 4 2]
#  [7 0 3]
#  [6 8 5]]
#
# [[4 8 2]
#  [1 0 3]
#  [7 6 5]]
#
# [[4 2 0]
#  [1 8 3]
#  [7 6 5]]
#
# [[8 1 2]
#  [7 4 3]
#  [6 5 0]]
#
# [[8 1 2]
#  [7 0 3]
#  [6 4 5]]
#
# [[8 1 2]
#  [4 6 3]
#  [7 5 0]]
#
# [[8 1 2]
#  [4 6 3]
#  [0 7 5]]
#
# [[8 1 2]
#  [4 3 5]
#  [7 6 0]]
#
# [[8 1 0]
#  [4 3 2]
#  [7 6 5]]
#
# [[8 2 0]
#  [4 1 3]
#  [7 6 5]]
#
# [[0 8 2]
#  [4 1 3]
#  [7 6 5]]
#
# [[1 3 4]
#  [8 5 6]
#  [7 2 0]]
#
# [[1 3 0]
#  [8 5 4]
#  [7 2 6]]
#
# [[1 4 0]
#  [8 3 5]
#  [7 2 6]]
#
# [[0 1 4]
#  [8 3 5]
#  [7 2 6]]
#
# [[1 3 4]
#  [7 8 5]
#  [0 2 6]]
#
# [[0 3 4]
#  [1 8 5]
#  [7 2 6]]
#
# [[1 3 4]
#  [2 0 5]
#  [8 7 6]]
#
# [[0 3 4]
#  [1 2 5]
#  [8 7 6]]
#
# [[1 3 0]
#  [8 6 4]
#  [7 5 2]]
#
# [[1 3 4]
#  [8 0 6]
#  [7 5 2]]
#
# [[1 3 4]
#  [6 0 2]
#  [8 7 5]]
#
# [[0 3 4]
#  [1 6 2]
#  [8 7 5]]
#
# [[8 1 4]
#  [7 3 2]
#  [0 6 5]]
#
# [[8 1 4]
#  [3 0 2]
#  [7 6 5]]
#
# [[1 3 4]
#  [7 8 2]
#  [6 5 0]]
#
# [[1 3 4]
#  [7 0 2]
#  [6 8 5]]
#
# [[3 8 4]
#  [1 0 2]
#  [7 6 5]]
#
# [[3 4 0]
#  [1 8 2]
#  [7 6 5]]
#
# [[8 1 0]
#  [7 2 3]
#  [6 5 4]]
#
# [[8 1 3]
#  [7 0 2]
#  [6 5 4]]
#
# [[8 1 3]
#  [7 4 5]
#  [6 2 0]]
#
# [[8 1 0]
#  [7 4 3]
#  [6 2 5]]
#
# [[8 3 0]
#  [7 1 4]
#  [6 2 5]]
#
# [[0 8 3]
#  [7 1 4]
#  [6 2 5]]
#
# [[8 1 3]
#  [6 7 4]
#  [0 2 5]]
#
# [[0 1 3]
#  [8 7 4]
#  [6 2 5]]
#
# [[8 1 0]
#  [2 6 3]
#  [7 5 4]]
#
# [[8 1 3]
#  [2 0 6]
#  [7 5 4]]
#
# [[8 1 3]
#  [6 0 4]
#  [2 7 5]]
#
# [[0 1 3]
#  [8 6 4]
#  [2 7 5]]
#
# [[8 1 3]
#  [2 0 5]
#  [7 4 6]]
#
# [[8 1 3]
#  [2 4 5]
#  [0 7 6]]
#
# [[8 4 1]
#  [2 0 3]
#  [7 6 5]]
#
# [[0 8 1]
#  [2 4 3]
#  [7 6 5]]
#
# [[8 3 4]
#  [2 1 5]
#  [7 6 0]]
#
# [[8 3 4]
#  [2 0 1]
#  [7 6 5]]
#
# [[1 8 2]
#  [7 0 3]
#  [6 5 4]]
#
# [[0 1 2]
#  [7 8 3]
#  [6 5 4]]
#
# [[1 2 3]
#  [7 5 8]
#  [6 4 0]]
#
# [[1 2 3]
#  [7 5 8]
#  [0 6 4]]
#
# [[1 3 0]
#  [7 2 8]
#  [6 5 4]]
#
# [[0 1 3]
#  [7 2 8]
#  [6 5 4]]
#
# [[1 2 3]
#  [6 7 8]
#  [0 5 4]]
#
# [[0 2 3]
#  [1 7 8]
#  [6 5 4]]
#
# [[1 2 3]
#  [7 0 5]
#  [6 4 8]]
#
# [[1 2 3]
#  [7 4 5]
#  [0 6 8]]
#
# [[1 4 2]
#  [7 0 3]
#  [6 8 5]]
#
# [[0 1 2]
#  [7 4 3]
#  [6 8 5]]
#
# [[1 3 4]
#  [7 2 5]
#  [6 8 0]]
#
# [[1 3 4]
#  [7 0 2]
#  [6 8 5]]
#
# [[7 1 3]
#  [6 2 4]
#  [0 8 5]]
#
# [[7 1 3]
#  [2 0 4]
#  [6 8 5]]
#
# [[2 7 3]
#  [1 0 4]
#  [6 8 5]]
#
# [[2 3 0]
#  [1 7 4]
#  [6 8 5]]
#
# [[2 8 0]
#  [1 6 3]
#  [7 5 4]]
#
# [[2 8 3]
#  [1 0 6]
#  [7 5 4]]
#
# [[2 8 3]
#  [6 0 4]
#  [1 7 5]]
#
# [[0 8 3]
#  [2 6 4]
#  [1 7 5]]
#
# [[2 8 3]
#  [1 0 5]
#  [7 4 6]]
#
# [[2 8 3]
#  [1 4 5]
#  [0 7 6]]
#
# [[2 4 8]
#  [1 0 3]
#  [7 6 5]]
#
# [[0 2 8]
#  [1 4 3]
#  [7 6 5]]
#
# [[2 8 3]
#  [7 1 4]
#  [6 5 0]]
#
# [[2 8 3]
#  [7 0 4]
#  [6 1 5]]
#
# [[2 3 4]
#  [1 0 5]
#  [7 8 6]]
#
# [[2 3 4]
#  [1 8 5]
#  [0 7 6]]
#
# [[2 3 4]
#  [1 6 8]
#  [7 5 0]]
#
# [[2 3 4]
#  [1 6 8]
#  [0 7 5]]
#
# [[2 4 0]
#  [1 3 8]
#  [7 6 5]]
#
# [[0 2 4]
#  [1 3 8]
#  [7 6 5]]
#
# [[2 3 4]
#  [7 1 8]
#  [0 6 5]]
#
# [[0 3 4]
#  [2 1 8]
#  [7 6 5]]
#
# Current Level :-  9
# All Possible States :-
# ----------------------------------
#
# [[1 6 2]
#  [8 5 0]
#  [7 4 3]]
#
# [[1 6 2]
#  [0 5 3]
#  [8 7 4]]
#
# [[1 6 2]
#  [8 3 4]
#  [7 0 5]]
#
# [[1 0 6]
#  [8 3 2]
#  [7 5 4]]
#
# [[1 6 2]
#  [7 8 3]
#  [5 0 4]]
#
# [[6 0 2]
#  [1 8 3]
#  [7 5 4]]
#
# [[8 1 2]
#  [7 6 3]
#  [5 0 4]]
#
# [[8 1 2]
#  [6 5 3]
#  [7 0 4]]
#
# [[8 1 2]
#  [6 3 0]
#  [7 5 4]]
#
# [[8 0 2]
#  [6 1 3]
#  [7 5 4]]
#
# [[1 2 3]
#  [5 7 6]
#  [8 0 4]]
#
# [[1 2 3]
#  [5 6 0]
#  [8 7 4]]
#
# [[1 0 3]
#  [5 2 6]
#  [8 7 4]]
#
# [[2 0 3]
#  [1 5 6]
#  [8 7 4]]
#
# [[1 3 6]
#  [8 2 4]
#  [7 0 5]]
#
# [[1 3 6]
#  [8 5 2]
#  [7 0 4]]
#
# [[1 0 6]
#  [8 3 2]
#  [7 5 4]]
#
# [[1 3 6]
#  [0 8 2]
#  [7 5 4]]
#
# [[8 1 3]
#  [7 2 6]
#  [5 0 4]]
#
# [[8 1 3]
#  [2 5 6]
#  [7 0 4]]
#
# [[8 0 3]
#  [2 1 6]
#  [7 5 4]]
#
# [[1 2 3]
#  [7 8 0]
#  [5 4 6]]
#
# [[1 2 3]
#  [7 6 0]
#  [5 8 4]]
#
# [[1 0 3]
#  [7 2 6]
#  [5 8 4]]
#
# [[1 2 3]
#  [0 7 6]
#  [5 8 4]]
#
# [[2 8 3]
#  [1 5 6]
#  [7 0 4]]
#
# [[2 8 3]
#  [0 1 6]
#  [7 5 4]]
#
# [[2 3 6]
#  [1 8 0]
#  [7 5 4]]
#
# [[1 0 2]
#  [6 7 3]
#  [8 5 4]]
#
# [[1 2 3]
#  [6 5 7]
#  [8 0 4]]
#
# [[1 0 3]
#  [6 2 7]
#  [8 5 4]]
#
# [[1 2 3]
#  [0 6 7]
#  [8 5 4]]
#
# [[1 2 3]
#  [6 5 0]
#  [8 4 7]]
#
# [[1 0 3]
#  [6 2 5]
#  [8 4 7]]
#
# [[1 2 3]
#  [0 6 5]
#  [8 4 7]]
#
# [[1 2 3]
#  [0 4 5]
#  [6 8 7]]
#
# [[1 4 2]
#  [6 7 3]
#  [8 0 5]]
#
# [[1 4 2]
#  [6 3 0]
#  [8 7 5]]
#
# [[6 1 2]
#  [0 4 3]
#  [8 7 5]]
#
# [[1 3 4]
#  [6 2 5]
#  [8 0 7]]
#
# [[1 3 4]
#  [6 7 2]
#  [8 0 5]]
#
# [[1 0 4]
#  [6 3 2]
#  [8 7 5]]
#
# [[6 1 3]
#  [8 2 4]
#  [7 0 5]]
#
# [[6 1 3]
#  [2 7 4]
#  [8 0 5]]
#
# [[6 1 3]
#  [2 4 0]
#  [8 7 5]]
#
# [[6 0 3]
#  [2 1 4]
#  [8 7 5]]
#
# [[2 6 3]
#  [1 7 0]
#  [8 5 4]]
#
# [[2 6 3]
#  [0 7 4]
#  [1 8 5]]
#
# [[2 6 3]
#  [1 4 5]
#  [8 0 7]]
#
# [[2 0 6]
#  [1 4 3]
#  [8 7 5]]
#
# [[2 6 3]
#  [8 1 4]
#  [7 0 5]]
#
# [[6 0 3]
#  [2 1 4]
#  [8 7 5]]
#
# [[2 3 4]
#  [1 6 5]
#  [8 0 7]]
#
# [[2 3 4]
#  [1 7 6]
#  [8 0 5]]
#
# [[2 0 4]
#  [1 3 6]
#  [8 7 5]]
#
# [[2 3 4]
#  [0 1 6]
#  [8 7 5]]
#
# [[1 5 2]
#  [8 4 3]
#  [7 0 6]]
#
# [[1 5 2]
#  [8 3 0]
#  [7 4 6]]
#
# [[1 5 2]
#  [0 8 3]
#  [7 4 6]]
#
# [[8 1 2]
#  [0 5 3]
#  [7 4 6]]
#
# [[1 3 5]
#  [8 2 6]
#  [7 0 4]]
#
# [[1 3 5]
#  [8 4 2]
#  [7 0 6]]
#
# [[1 0 5]
#  [8 3 2]
#  [7 4 6]]
#
# [[1 3 5]
#  [0 8 2]
#  [7 4 6]]
#
# [[8 1 3]
#  [7 2 5]
#  [4 0 6]]
#
# [[8 1 3]
#  [2 5 0]
#  [7 4 6]]
#
# [[8 0 3]
#  [2 1 5]
#  [7 4 6]]
#
# [[1 2 3]
#  [7 8 0]
#  [4 6 5]]
#
# [[1 2 3]
#  [7 5 0]
#  [4 8 6]]
#
# [[1 0 3]
#  [7 2 5]
#  [4 8 6]]
#
# [[1 2 3]
#  [0 7 5]
#  [4 8 6]]
#
# [[2 8 3]
#  [1 5 0]
#  [7 4 6]]
#
# [[2 8 3]
#  [0 1 5]
#  [7 4 6]]
#
# [[2 3 5]
#  [1 8 0]
#  [7 4 6]]
#
# [[1 2 3]
#  [4 7 0]
#  [8 6 5]]
#
# [[1 2 3]
#  [0 7 5]
#  [4 8 6]]
#
# [[1 2 3]
#  [4 5 6]
#  [8 0 7]]
#
# [[1 0 2]
#  [4 5 3]
#  [8 7 6]]
#
# [[1 3 5]
#  [4 2 0]
#  [8 7 6]]
#
# [[4 1 3]
#  [0 2 5]
#  [8 7 6]]
#
# [[2 4 3]
#  [1 7 5]
#  [8 0 6]]
#
# [[2 4 3]
#  [1 5 0]
#  [8 7 6]]
#
# [[2 4 3]
#  [0 1 5]
#  [8 7 6]]
#
# [[2 3 5]
#  [1 4 0]
#  [8 7 6]]
#
# [[1 0 4]
#  [8 6 2]
#  [7 5 3]]
#
# [[1 4 2]
#  [8 5 6]
#  [7 0 3]]
#
# [[1 0 2]
#  [8 4 6]
#  [7 5 3]]
#
# [[1 4 2]
#  [0 8 6]
#  [7 5 3]]
#
# [[1 4 2]
#  [6 7 3]
#  [8 0 5]]
#
# [[1 4 2]
#  [6 3 0]
#  [8 7 5]]
#
# [[4 0 2]
#  [1 6 3]
#  [8 7 5]]
#
# [[1 4 2]
#  [8 5 0]
#  [7 3 6]]
#
# [[1 0 2]
#  [8 4 5]
#  [7 3 6]]
#
# [[1 4 2]
#  [0 8 5]
#  [7 3 6]]
#
# [[1 4 2]
#  [0 3 5]
#  [8 7 6]]
#
# [[1 4 2]
#  [7 8 0]
#  [6 5 3]]
#
# [[1 4 2]
#  [7 3 0]
#  [6 8 5]]
#
# [[1 4 2]
#  [0 7 3]
#  [6 8 5]]
#
# [[4 8 2]
#  [1 6 3]
#  [7 0 5]]
#
# [[4 8 2]
#  [1 3 0]
#  [7 6 5]]
#
# [[4 8 2]
#  [0 1 3]
#  [7 6 5]]
#
# [[4 2 3]
#  [1 8 0]
#  [7 6 5]]
#
# [[8 1 2]
#  [7 4 0]
#  [6 5 3]]
#
# [[8 1 2]
#  [7 3 0]
#  [6 4 5]]
#
# [[8 0 2]
#  [7 1 3]
#  [6 4 5]]
#
# [[8 1 2]
#  [0 7 3]
#  [6 4 5]]
#
# [[8 1 2]
#  [4 6 0]
#  [7 5 3]]
#
# [[8 1 2]
#  [0 6 3]
#  [4 7 5]]
#
# [[8 1 2]
#  [4 3 5]
#  [7 0 6]]
#
# [[8 0 1]
#  [4 3 2]
#  [7 6 5]]
#
# [[8 2 3]
#  [4 1 0]
#  [7 6 5]]
#
# [[4 8 2]
#  [0 1 3]
#  [7 6 5]]
#
# [[1 3 4]
#  [8 5 6]
#  [7 0 2]]
#
# [[1 0 3]
#  [8 5 4]
#  [7 2 6]]
#
# [[1 4 5]
#  [8 3 0]
#  [7 2 6]]
#
# [[8 1 4]
#  [0 3 5]
#  [7 2 6]]
#
# [[1 3 4]
#  [7 8 5]
#  [2 0 6]]
#
# [[3 0 4]
#  [1 8 5]
#  [7 2 6]]
#
# [[1 3 4]
#  [2 7 5]
#  [8 0 6]]
#
# [[1 3 4]
#  [2 5 0]
#  [8 7 6]]
#
# [[1 0 4]
#  [2 3 5]
#  [8 7 6]]
#
# [[3 0 4]
#  [1 2 5]
#  [8 7 6]]
#
# [[1 0 3]
#  [8 6 4]
#  [7 5 2]]
#
# [[1 3 4]
#  [8 5 6]
#  [7 0 2]]
#
# [[1 0 4]
#  [8 3 6]
#  [7 5 2]]
#
# [[1 3 4]
#  [0 8 6]
#  [7 5 2]]
#
# [[1 3 4]
#  [6 7 2]
#  [8 0 5]]
#
# [[1 0 4]
#  [6 3 2]
#  [8 7 5]]
#
# [[3 0 4]
#  [1 6 2]
#  [8 7 5]]
#
# [[8 1 4]
#  [7 3 2]
#  [6 0 5]]
#
# [[8 1 4]
#  [3 6 2]
#  [7 0 5]]
#
# [[8 1 4]
#  [3 2 0]
#  [7 6 5]]
#
# [[8 0 4]
#  [3 1 2]
#  [7 6 5]]
#
# [[1 3 4]
#  [7 8 0]
#  [6 5 2]]
#
# [[1 0 4]
#  [7 3 2]
#  [6 8 5]]
#
# [[1 3 4]
#  [0 7 2]
#  [6 8 5]]
#
# [[3 8 4]
#  [1 6 2]
#  [7 0 5]]
#
# [[3 8 4]
#  [1 2 0]
#  [7 6 5]]
#
# [[3 8 4]
#  [0 1 2]
#  [7 6 5]]
#
# [[3 4 2]
#  [1 8 0]
#  [7 6 5]]
#
# [[8 0 1]
#  [7 2 3]
#  [6 5 4]]
#
# [[8 1 3]
#  [7 5 2]
#  [6 0 4]]
#
# [[8 0 3]
#  [7 1 2]
#  [6 5 4]]
#
# [[8 1 3]
#  [0 7 2]
#  [6 5 4]]
#
# [[8 1 3]
#  [7 4 5]
#  [6 0 2]]
#
# [[8 0 1]
#  [7 4 3]
#  [6 2 5]]
#
# [[8 3 4]
#  [7 1 0]
#  [6 2 5]]
#
# [[7 8 3]
#  [0 1 4]
#  [6 2 5]]
#
# [[8 1 3]
#  [6 7 4]
#  [2 0 5]]
#
# [[1 0 3]
#  [8 7 4]
#  [6 2 5]]
#
# [[8 0 1]
#  [2 6 3]
#  [7 5 4]]
#
# [[8 1 3]
#  [2 5 6]
#  [7 0 4]]
#
# [[8 0 3]
#  [2 1 6]
#  [7 5 4]]
#
# [[8 1 3]
#  [6 7 4]
#  [2 0 5]]
#
# [[8 1 3]
#  [6 4 0]
#  [2 7 5]]
#
# [[8 0 3]
#  [6 1 4]
#  [2 7 5]]
#
# [[1 0 3]
#  [8 6 4]
#  [2 7 5]]
#
# [[8 1 3]
#  [2 5 0]
#  [7 4 6]]
#
# [[8 0 3]
#  [2 1 5]
#  [7 4 6]]
#
# [[8 1 3]
#  [0 4 5]
#  [2 7 6]]
#
# [[8 4 1]
#  [2 6 3]
#  [7 0 5]]
#
# [[8 4 1]
#  [2 3 0]
#  [7 6 5]]
#
# [[8 4 1]
#  [0 2 3]
#  [7 6 5]]
#
# [[2 8 1]
#  [0 4 3]
#  [7 6 5]]
#
# [[8 3 4]
#  [2 1 5]
#  [7 0 6]]
#
# [[8 3 4]
#  [2 6 1]
#  [7 0 5]]
#
# [[8 0 4]
#  [2 3 1]
#  [7 6 5]]
#
# [[8 3 4]
#  [0 2 1]
#  [7 6 5]]
#
# [[1 8 2]
#  [7 5 3]
#  [6 0 4]]
#
# [[1 8 2]
#  [7 3 0]
#  [6 5 4]]
#
# [[1 8 2]
#  [0 7 3]
#  [6 5 4]]
#
# [[7 1 2]
#  [0 8 3]
#  [6 5 4]]
#
# [[1 2 3]
#  [7 5 0]
#  [6 4 8]]
#
# [[1 2 3]
#  [0 5 8]
#  [7 6 4]]
#
# [[1 3 8]
#  [7 2 0]
#  [6 5 4]]
#
# [[7 1 3]
#  [0 2 8]
#  [6 5 4]]
#
# [[1 2 3]
#  [6 7 8]
#  [5 0 4]]
#
# [[2 0 3]
#  [1 7 8]
#  [6 5 4]]
#
# [[1 2 3]
#  [7 5 0]
#  [6 4 8]]
#
# [[1 0 3]
#  [7 2 5]
#  [6 4 8]]
#
# [[1 2 3]
#  [0 7 5]
#  [6 4 8]]
#
# [[1 2 3]
#  [0 4 5]
#  [7 6 8]]
#
# [[1 4 2]
#  [7 3 0]
#  [6 8 5]]
#
# [[1 4 2]
#  [0 7 3]
#  [6 8 5]]
#
# [[7 1 2]
#  [0 4 3]
#  [6 8 5]]
#
# [[1 3 4]
#  [7 2 5]
#  [6 0 8]]
#
# [[1 0 4]
#  [7 3 2]
#  [6 8 5]]
#
# [[1 3 4]
#  [0 7 2]
#  [6 8 5]]
#
# [[7 1 3]
#  [6 2 4]
#  [8 0 5]]
#
# [[7 1 3]
#  [2 8 4]
#  [6 0 5]]
#
# [[7 1 3]
#  [2 4 0]
#  [6 8 5]]
#
# [[7 0 3]
#  [2 1 4]
#  [6 8 5]]
#
# [[2 7 3]
#  [1 8 4]
#  [6 0 5]]
#
# [[2 7 3]
#  [1 4 0]
#  [6 8 5]]
#
# [[2 7 3]
#  [0 1 4]
#  [6 8 5]]
#
# [[2 3 4]
#  [1 7 0]
#  [6 8 5]]
#
# [[2 0 8]
#  [1 6 3]
#  [7 5 4]]
#
# [[2 8 3]
#  [1 5 6]
#  [7 0 4]]
#
# [[2 8 3]
#  [0 1 6]
#  [7 5 4]]
#
# [[2 8 3]
#  [6 7 4]
#  [1 0 5]]
#
# [[2 8 3]
#  [6 4 0]
#  [1 7 5]]
#
# [[2 0 3]
#  [6 8 4]
#  [1 7 5]]
#
# [[8 0 3]
#  [2 6 4]
#  [1 7 5]]
#
# [[2 8 3]
#  [1 5 0]
#  [7 4 6]]
#
# [[2 8 3]
#  [0 1 5]
#  [7 4 6]]
#
# [[2 8 3]
#  [0 4 5]
#  [1 7 6]]
#
# [[2 4 8]
#  [1 6 3]
#  [7 0 5]]
#
# [[2 4 8]
#  [1 3 0]
#  [7 6 5]]
#
# [[2 4 8]
#  [0 1 3]
#  [7 6 5]]
#
# [[1 2 8]
#  [0 4 3]
#  [7 6 5]]
#
# [[2 8 3]
#  [7 1 0]
#  [6 5 4]]
#
# [[2 8 3]
#  [7 4 0]
#  [6 1 5]]
#
# [[2 0 3]
#  [7 8 4]
#  [6 1 5]]
#
# [[2 8 3]
#  [0 7 4]
#  [6 1 5]]
#
# [[2 3 4]
#  [1 5 0]
#  [7 8 6]]
#
# [[2 0 4]
#  [1 3 5]
#  [7 8 6]]
#
# [[2 3 4]
#  [0 1 5]
#  [7 8 6]]
#
# [[2 3 4]
#  [0 8 5]
#  [1 7 6]]
#
# [[2 3 4]
#  [1 6 0]
#  [7 5 8]]
#
# [[2 3 4]
#  [0 6 8]
#  [1 7 5]]
#
# [[2 4 8]
#  [1 3 0]
#  [7 6 5]]
#
# [[1 2 4]
#  [0 3 8]
#  [7 6 5]]
#
# [[2 3 4]
#  [7 1 8]
#  [6 0 5]]
#
# [[3 0 4]
#  [2 1 8]
#  [7 6 5]]
#
# Current Level :-  10
# All Possible States :-
# ----------------------------------
#
# [[1 6 0]
#  [8 5 2]
#  [7 4 3]]
#
# [[1 6 2]
#  [8 0 5]
#  [7 4 3]]
#
# [[1 6 2]
#  [5 0 3]
#  [8 7 4]]
#
# [[0 6 2]
#  [1 5 3]
#  [8 7 4]]
#
# [[1 6 2]
#  [8 0 4]
#  [7 3 5]]
#
# [[1 6 2]
#  [8 3 4]
#  [0 7 5]]
#
# [[0 1 6]
#  [8 3 2]
#  [7 5 4]]
#
# [[1 6 2]
#  [7 8 3]
#  [5 4 0]]
#
# [[1 6 2]
#  [7 0 3]
#  [5 8 4]]
#
# [[6 8 2]
#  [1 0 3]
#  [7 5 4]]
#
# [[6 2 0]
#  [1 8 3]
#  [7 5 4]]
#
# [[8 1 2]
#  [7 6 3]
#  [5 4 0]]
#
# [[8 1 2]
#  [7 0 3]
#  [5 6 4]]
#
# [[8 1 2]
#  [6 5 3]
#  [7 4 0]]
#
# [[8 1 2]
#  [6 5 3]
#  [0 7 4]]
#
# [[8 1 2]
#  [6 3 4]
#  [7 5 0]]
#
# [[8 1 0]
#  [6 3 2]
#  [7 5 4]]
#
# [[8 2 0]
#  [6 1 3]
#  [7 5 4]]
#
# [[0 8 2]
#  [6 1 3]
#  [7 5 4]]
#
# [[1 2 3]
#  [5 7 6]
#  [8 4 0]]
#
# [[1 2 3]
#  [5 7 6]
#  [0 8 4]]
#
# [[1 2 3]
#  [5 6 4]
#  [8 7 0]]
#
# [[1 2 0]
#  [5 6 3]
#  [8 7 4]]
#
# [[1 3 0]
#  [5 2 6]
#  [8 7 4]]
#
# [[0 1 3]
#  [5 2 6]
#  [8 7 4]]
#
# [[2 5 3]
#  [1 0 6]
#  [8 7 4]]
#
# [[2 3 0]
#  [1 5 6]
#  [8 7 4]]
#
# [[1 3 6]
#  [8 0 4]
#  [7 2 5]]
#
# [[1 3 6]
#  [8 2 4]
#  [0 7 5]]
#
# [[1 3 6]
#  [8 5 2]
#  [7 4 0]]
#
# [[1 3 6]
#  [8 5 2]
#  [0 7 4]]
#
# [[0 1 6]
#  [8 3 2]
#  [7 5 4]]
#
# [[1 3 6]
#  [7 8 2]
#  [0 5 4]]
#
# [[0 3 6]
#  [1 8 2]
#  [7 5 4]]
#
# [[8 1 3]
#  [7 2 6]
#  [5 4 0]]
#
# [[8 1 3]
#  [7 0 6]
#  [5 2 4]]
#
# [[8 1 3]
#  [2 5 6]
#  [7 4 0]]
#
# [[8 1 3]
#  [2 5 6]
#  [0 7 4]]
#
# [[8 3 0]
#  [2 1 6]
#  [7 5 4]]
#
# [[0 8 3]
#  [2 1 6]
#  [7 5 4]]
#
# [[1 2 0]
#  [7 8 3]
#  [5 4 6]]
#
# [[1 2 3]
#  [7 0 8]
#  [5 4 6]]
#
# [[1 2 3]
#  [7 6 4]
#  [5 8 0]]
#
# [[1 2 0]
#  [7 6 3]
#  [5 8 4]]
#
# [[1 3 0]
#  [7 2 6]
#  [5 8 4]]
#
# [[0 1 3]
#  [7 2 6]
#  [5 8 4]]
#
# [[1 2 3]
#  [5 7 6]
#  [0 8 4]]
#
# [[0 2 3]
#  [1 7 6]
#  [5 8 4]]
#
# [[2 8 3]
#  [1 5 6]
#  [7 4 0]]
#
# [[2 8 3]
#  [1 5 6]
#  [0 7 4]]
#
# [[2 8 3]
#  [7 1 6]
#  [0 5 4]]
#
# [[0 8 3]
#  [2 1 6]
#  [7 5 4]]
#
# [[2 3 6]
#  [1 8 4]
#  [7 5 0]]
#
# [[2 3 6]
#  [1 0 8]
#  [7 5 4]]
#
# [[1 7 2]
#  [6 0 3]
#  [8 5 4]]
#
# [[0 1 2]
#  [6 7 3]
#  [8 5 4]]
#
# [[1 2 3]
#  [6 5 7]
#  [8 4 0]]
#
# [[1 2 3]
#  [6 5 7]
#  [0 8 4]]
#
# [[1 3 0]
#  [6 2 7]
#  [8 5 4]]
#
# [[0 1 3]
#  [6 2 7]
#  [8 5 4]]
#
# [[1 2 3]
#  [8 6 7]
#  [0 5 4]]
#
# [[0 2 3]
#  [1 6 7]
#  [8 5 4]]
#
# [[1 2 3]
#  [6 5 7]
#  [8 4 0]]
#
# [[1 2 0]
#  [6 5 3]
#  [8 4 7]]
#
# [[1 3 0]
#  [6 2 5]
#  [8 4 7]]
#
# [[0 1 3]
#  [6 2 5]
#  [8 4 7]]
#
# [[1 2 3]
#  [8 6 5]
#  [0 4 7]]
#
# [[0 2 3]
#  [1 6 5]
#  [8 4 7]]
#
# [[1 2 3]
#  [4 0 5]
#  [6 8 7]]
#
# [[0 2 3]
#  [1 4 5]
#  [6 8 7]]
#
# [[1 4 2]
#  [6 7 3]
#  [8 5 0]]
#
# [[1 4 2]
#  [6 7 3]
#  [0 8 5]]
#
# [[1 4 2]
#  [6 3 5]
#  [8 7 0]]
#
# [[1 4 0]
#  [6 3 2]
#  [8 7 5]]
#
# [[6 1 2]
#  [8 4 3]
#  [0 7 5]]
#
# [[6 1 2]
#  [4 0 3]
#  [8 7 5]]
#
# [[1 3 4]
#  [6 0 5]
#  [8 2 7]]
#
# [[1 3 4]
#  [6 2 5]
#  [0 8 7]]
#
# [[1 3 4]
#  [6 7 2]
#  [8 5 0]]
#
# [[1 3 4]
#  [6 7 2]
#  [0 8 5]]
#
# [[1 4 0]
#  [6 3 2]
#  [8 7 5]]
#
# [[0 1 4]
#  [6 3 2]
#  [8 7 5]]
#
# [[6 1 3]
#  [8 2 4]
#  [7 5 0]]
#
# [[6 1 3]
#  [8 0 4]
#  [7 2 5]]
#
# [[6 1 3]
#  [2 7 4]
#  [8 5 0]]
#
# [[6 1 3]
#  [2 7 4]
#  [0 8 5]]
#
# [[6 1 3]
#  [2 4 5]
#  [8 7 0]]
#
# [[6 1 0]
#  [2 4 3]
#  [8 7 5]]
#
# [[6 3 0]
#  [2 1 4]
#  [8 7 5]]
#
# [[2 6 0]
#  [1 7 3]
#  [8 5 4]]
#
# [[2 6 3]
#  [1 0 7]
#  [8 5 4]]
#
# [[2 6 3]
#  [7 0 4]
#  [1 8 5]]
#
# [[0 6 3]
#  [2 7 4]
#  [1 8 5]]
#
# [[2 6 3]
#  [1 0 5]
#  [8 4 7]]
#
# [[2 6 3]
#  [1 4 5]
#  [0 8 7]]
#
# [[2 4 6]
#  [1 0 3]
#  [8 7 5]]
#
# [[0 2 6]
#  [1 4 3]
#  [8 7 5]]
#
# [[2 6 3]
#  [8 1 4]
#  [7 5 0]]
#
# [[2 6 3]
#  [8 0 4]
#  [7 1 5]]
#
# [[6 3 0]
#  [2 1 4]
#  [8 7 5]]
#
# [[2 3 4]
#  [1 0 5]
#  [8 6 7]]
#
# [[2 3 4]
#  [1 6 5]
#  [0 8 7]]
#
# [[2 3 4]
#  [1 7 6]
#  [8 5 0]]
#
# [[2 3 4]
#  [1 7 6]
#  [0 8 5]]
#
# [[2 4 0]
#  [1 3 6]
#  [8 7 5]]
#
# [[0 2 4]
#  [1 3 6]
#  [8 7 5]]
#
# [[2 3 4]
#  [8 1 6]
#  [0 7 5]]
#
# [[0 3 4]
#  [2 1 6]
#  [8 7 5]]
#
# [[1 5 2]
#  [8 4 3]
#  [7 6 0]]
#
# [[1 5 2]
#  [8 4 3]
#  [0 7 6]]
#
# [[1 5 2]
#  [8 3 6]
#  [7 4 0]]
#
# [[1 5 0]
#  [8 3 2]
#  [7 4 6]]
#
# [[1 5 2]
#  [7 8 3]
#  [0 4 6]]
#
# [[0 5 2]
#  [1 8 3]
#  [7 4 6]]
#
# [[8 1 2]
#  [7 5 3]
#  [0 4 6]]
#
# [[8 1 2]
#  [5 0 3]
#  [7 4 6]]
#
# [[1 3 5]
#  [8 0 6]
#  [7 2 4]]
#
# [[1 3 5]
#  [8 2 6]
#  [0 7 4]]
#
# [[1 3 5]
#  [8 4 2]
#  [7 6 0]]
#
# [[1 3 5]
#  [8 4 2]
#  [0 7 6]]
#
# [[1 5 0]
#  [8 3 2]
#  [7 4 6]]
#
# [[0 1 5]
#  [8 3 2]
#  [7 4 6]]
#
# [[1 3 5]
#  [7 8 2]
#  [0 4 6]]
#
# [[0 3 5]
#  [1 8 2]
#  [7 4 6]]
#
# [[8 1 3]
#  [7 2 5]
#  [4 6 0]]
#
# [[8 1 3]
#  [7 0 5]
#  [4 2 6]]
#
# [[8 1 3]
#  [2 5 6]
#  [7 4 0]]
#
# [[8 1 0]
#  [2 5 3]
#  [7 4 6]]
#
# [[8 3 0]
#  [2 1 5]
#  [7 4 6]]
#
# [[0 8 3]
#  [2 1 5]
#  [7 4 6]]
#
# [[1 2 0]
#  [7 8 3]
#  [4 6 5]]
#
# [[1 2 3]
#  [7 0 8]
#  [4 6 5]]
#
# [[1 2 3]
#  [7 5 6]
#  [4 8 0]]
#
# [[1 2 0]
#  [7 5 3]
#  [4 8 6]]
#
# [[1 3 0]
#  [7 2 5]
#  [4 8 6]]
#
# [[0 1 3]
#  [7 2 5]
#  [4 8 6]]
#
# [[0 2 3]
#  [1 7 5]
#  [4 8 6]]
#
# [[2 8 3]
#  [1 5 6]
#  [7 4 0]]
#
# [[2 8 0]
#  [1 5 3]
#  [7 4 6]]
#
# [[2 8 3]
#  [7 1 5]
#  [0 4 6]]
#
# [[0 8 3]
#  [2 1 5]
#  [7 4 6]]
#
# [[2 3 5]
#  [1 8 6]
#  [7 4 0]]
#
# [[2 3 5]
#  [1 0 8]
#  [7 4 6]]
#
# [[1 2 0]
#  [4 7 3]
#  [8 6 5]]
#
# [[1 2 3]
#  [4 0 7]
#  [8 6 5]]
#
# [[0 2 3]
#  [1 7 5]
#  [4 8 6]]
#
# [[1 2 3]
#  [4 0 6]
#  [8 5 7]]
#
# [[1 2 3]
#  [4 5 6]
#  [0 8 7]]
#
# [[1 5 2]
#  [4 0 3]
#  [8 7 6]]
#
# [[0 1 2]
#  [4 5 3]
#  [8 7 6]]
#
# [[1 3 5]
#  [4 2 6]
#  [8 7 0]]
#
# [[1 3 5]
#  [4 0 2]
#  [8 7 6]]
#
# [[4 1 3]
#  [8 2 5]
#  [0 7 6]]
#
# [[4 1 3]
#  [2 0 5]
#  [8 7 6]]
#
# [[2 4 3]
#  [1 7 5]
#  [8 6 0]]
#
# [[2 4 3]
#  [1 7 5]
#  [0 8 6]]
#
# [[2 4 3]
#  [1 5 6]
#  [8 7 0]]
#
# [[2 4 0]
#  [1 5 3]
#  [8 7 6]]
#
# [[2 4 3]
#  [8 1 5]
#  [0 7 6]]
#
# [[0 4 3]
#  [2 1 5]
#  [8 7 6]]
#
# [[2 3 5]
#  [1 4 6]
#  [8 7 0]]
#
# [[2 3 5]
#  [1 0 4]
#  [8 7 6]]
#
# [[1 6 4]
#  [8 0 2]
#  [7 5 3]]
#
# [[0 1 4]
#  [8 6 2]
#  [7 5 3]]
#
# [[1 4 2]
#  [8 5 6]
#  [7 3 0]]
#
# [[1 4 2]
#  [8 5 6]
#  [0 7 3]]
#
# [[1 2 0]
#  [8 4 6]
#  [7 5 3]]
#
# [[0 1 2]
#  [8 4 6]
#  [7 5 3]]
#
# [[1 4 2]
#  [7 8 6]
#  [0 5 3]]
#
# [[0 4 2]
#  [1 8 6]
#  [7 5 3]]
#
# [[1 4 2]
#  [6 7 3]
#  [8 5 0]]
#
# [[1 4 2]
#  [6 7 3]
#  [0 8 5]]
#
# [[1 4 2]
#  [6 3 5]
#  [8 7 0]]
#
# [[1 4 0]
#  [6 3 2]
#  [8 7 5]]
#
# [[4 6 2]
#  [1 0 3]
#  [8 7 5]]
#
# [[4 2 0]
#  [1 6 3]
#  [8 7 5]]
#
# [[1 4 2]
#  [8 5 6]
#  [7 3 0]]
#
# [[1 4 0]
#  [8 5 2]
#  [7 3 6]]
#
# [[1 2 0]
#  [8 4 5]
#  [7 3 6]]
#
# [[0 1 2]
#  [8 4 5]
#  [7 3 6]]
#
# [[1 4 2]
#  [7 8 5]
#  [0 3 6]]
#
# [[0 4 2]
#  [1 8 5]
#  [7 3 6]]
#
# [[1 4 2]
#  [3 0 5]
#  [8 7 6]]
#
# [[0 4 2]
#  [1 3 5]
#  [8 7 6]]
#
# [[1 4 0]
#  [7 8 2]
#  [6 5 3]]
#
# [[1 4 2]
#  [7 0 8]
#  [6 5 3]]
#
# [[1 4 2]
#  [7 3 5]
#  [6 8 0]]
#
# [[1 4 0]
#  [7 3 2]
#  [6 8 5]]
#
# [[1 4 2]
#  [6 7 3]
#  [0 8 5]]
#
# [[0 4 2]
#  [1 7 3]
#  [6 8 5]]
#
# [[4 8 2]
#  [1 6 3]
#  [7 5 0]]
#
# [[4 8 2]
#  [1 6 3]
#  [0 7 5]]
#
# [[4 8 2]
#  [1 3 5]
#  [7 6 0]]
#
# [[4 8 0]
#  [1 3 2]
#  [7 6 5]]
#
# [[4 8 2]
#  [7 1 3]
#  [0 6 5]]
#
# [[4 2 3]
#  [1 8 5]
#  [7 6 0]]
#
# [[4 2 3]
#  [1 0 8]
#  [7 6 5]]
#
# [[8 1 0]
#  [7 4 2]
#  [6 5 3]]
#
# [[8 1 2]
#  [7 0 4]
#  [6 5 3]]
#
# [[8 1 2]
#  [7 3 5]
#  [6 4 0]]
#
# [[8 1 0]
#  [7 3 2]
#  [6 4 5]]
#
# [[8 2 0]
#  [7 1 3]
#  [6 4 5]]
#
# [[0 8 2]
#  [7 1 3]
#  [6 4 5]]
#
# [[8 1 2]
#  [6 7 3]
#  [0 4 5]]
#
# [[0 1 2]
#  [8 7 3]
#  [6 4 5]]
#
# [[8 1 0]
#  [4 6 2]
#  [7 5 3]]
#
# [[8 1 2]
#  [4 0 6]
#  [7 5 3]]
#
# [[8 1 2]
#  [6 0 3]
#  [4 7 5]]
#
# [[0 1 2]
#  [8 6 3]
#  [4 7 5]]
#
# [[8 1 2]
#  [4 0 5]
#  [7 3 6]]
#
# [[8 1 2]
#  [4 3 5]
#  [0 7 6]]
#
# [[8 3 1]
#  [4 0 2]
#  [7 6 5]]
#
# [[0 8 1]
#  [4 3 2]
#  [7 6 5]]
#
# [[8 2 3]
#  [4 1 5]
#  [7 6 0]]
#
# [[8 2 3]
#  [4 0 1]
#  [7 6 5]]
#
# [[4 8 2]
#  [7 1 3]
#  [0 6 5]]
#
# [[1 3 4]
#  [8 5 6]
#  [0 7 2]]
#
# [[1 5 3]
#  [8 0 4]
#  [7 2 6]]
#
# [[0 1 3]
#  [8 5 4]
#  [7 2 6]]
#
# [[1 4 5]
#  [8 3 6]
#  [7 2 0]]
#
# [[1 4 5]
#  [8 0 3]
#  [7 2 6]]
#
# [[8 1 4]
#  [7 3 5]
#  [0 2 6]]
#
# [[8 1 4]
#  [3 0 5]
#  [7 2 6]]
#
# [[1 3 4]
#  [7 8 5]
#  [2 6 0]]
#
# [[1 3 4]
#  [7 0 5]
#  [2 8 6]]
#
# [[3 8 4]
#  [1 0 5]
#  [7 2 6]]
#
# [[3 4 0]
#  [1 8 5]
#  [7 2 6]]
#
# [[1 3 4]
#  [2 7 5]
#  [8 6 0]]
#
# [[1 3 4]
#  [2 7 5]
#  [0 8 6]]
#
# [[1 3 4]
#  [2 5 6]
#  [8 7 0]]
#
# [[1 3 0]
#  [2 5 4]
#  [8 7 6]]
#
# [[1 4 0]
#  [2 3 5]
#  [8 7 6]]
#
# [[0 1 4]
#  [2 3 5]
#  [8 7 6]]
#
# [[3 2 4]
#  [1 0 5]
#  [8 7 6]]
#
# [[3 4 0]
#  [1 2 5]
#  [8 7 6]]
#
# [[1 6 3]
#  [8 0 4]
#  [7 5 2]]
#
# [[0 1 3]
#  [8 6 4]
#  [7 5 2]]
#
# [[1 3 4]
#  [8 5 6]
#  [0 7 2]]
#
# [[1 4 0]
#  [8 3 6]
#  [7 5 2]]
#
# [[0 1 4]
#  [8 3 6]
#  [7 5 2]]
#
# [[1 3 4]
#  [7 8 6]
#  [0 5 2]]
#
# [[0 3 4]
#  [1 8 6]
#  [7 5 2]]
#
# [[1 3 4]
#  [6 7 2]
#  [8 5 0]]
#
# [[1 3 4]
#  [6 7 2]
#  [0 8 5]]
#
# [[1 4 0]
#  [6 3 2]
#  [8 7 5]]
#
# [[0 1 4]
#  [6 3 2]
#  [8 7 5]]
#
# [[3 6 4]
#  [1 0 2]
#  [8 7 5]]
#
# [[3 4 0]
#  [1 6 2]
#  [8 7 5]]
#
# [[8 1 4]
#  [7 3 2]
#  [6 5 0]]
#
# [[8 1 4]
#  [7 0 2]
#  [6 3 5]]
#
# [[8 1 4]
#  [3 6 2]
#  [7 5 0]]
#
# [[8 1 4]
#  [3 6 2]
#  [0 7 5]]
#
# [[8 1 4]
#  [3 2 5]
#  [7 6 0]]
#
# [[8 1 0]
#  [3 2 4]
#  [7 6 5]]
#
# [[8 4 0]
#  [3 1 2]
#  [7 6 5]]
#
# [[0 8 4]
#  [3 1 2]
#  [7 6 5]]
#
# [[1 3 0]
#  [7 8 4]
#  [6 5 2]]
#
# [[1 3 4]
#  [7 0 8]
#  [6 5 2]]
#
# [[1 4 0]
#  [7 3 2]
#  [6 8 5]]
#
# [[0 1 4]
#  [7 3 2]
#  [6 8 5]]
#
# [[1 3 4]
#  [6 7 2]
#  [0 8 5]]
#
# [[0 3 4]
#  [1 7 2]
#  [6 8 5]]
#
# [[3 8 4]
#  [1 6 2]
#  [7 5 0]]
#
# [[3 8 4]
#  [1 6 2]
#  [0 7 5]]
#
# [[3 8 4]
#  [1 2 5]
#  [7 6 0]]
#
# [[3 8 0]
#  [1 2 4]
#  [7 6 5]]
#
# [[3 8 4]
#  [7 1 2]
#  [0 6 5]]
#
# [[0 8 4]
#  [3 1 2]
#  [7 6 5]]
#
# [[3 4 2]
#  [1 8 5]
#  [7 6 0]]
#
# [[3 4 2]
#  [1 0 8]
#  [7 6 5]]
#
# [[8 2 1]
#  [7 0 3]
#  [6 5 4]]
#
# [[0 8 1]
#  [7 2 3]
#  [6 5 4]]
#
# [[8 1 3]
#  [7 5 2]
#  [6 4 0]]
#
# [[8 1 3]
#  [7 5 2]
#  [0 6 4]]
#
# [[8 3 0]
#  [7 1 2]
#  [6 5 4]]
#
# [[0 8 3]
#  [7 1 2]
#  [6 5 4]]
#
# [[8 1 3]
#  [6 7 2]
#  [0 5 4]]
#
# [[0 1 3]
#  [8 7 2]
#  [6 5 4]]
#
# [[8 1 3]
#  [7 0 5]
#  [6 4 2]]
#
# [[8 1 3]
#  [7 4 5]
#  [0 6 2]]
#
# [[8 4 1]
#  [7 0 3]
#  [6 2 5]]
#
# [[0 8 1]
#  [7 4 3]
#  [6 2 5]]
#
# [[8 3 4]
#  [7 1 5]
#  [6 2 0]]
#
# [[8 3 4]
#  [7 0 1]
#  [6 2 5]]
#
# [[7 8 3]
#  [6 1 4]
#  [0 2 5]]
#
# [[7 8 3]
#  [1 0 4]
#  [6 2 5]]
#
# [[8 1 3]
#  [6 7 4]
#  [2 5 0]]
#
# [[1 7 3]
#  [8 0 4]
#  [6 2 5]]
#
# [[1 3 0]
#  [8 7 4]
#  [6 2 5]]
#
# [[8 6 1]
#  [2 0 3]
#  [7 5 4]]
#
# [[0 8 1]
#  [2 6 3]
#  [7 5 4]]
#
# [[8 1 3]
#  [2 5 6]
#  [7 4 0]]
#
# [[8 1 3]
#  [2 5 6]
#  [0 7 4]]
#
# [[8 3 0]
#  [2 1 6]
#  [7 5 4]]
#
# [[0 8 3]
#  [2 1 6]
#  [7 5 4]]
#
# [[8 1 3]
#  [6 7 4]
#  [2 5 0]]
#
# [[8 1 3]
#  [6 4 5]
#  [2 7 0]]
#
# [[8 1 0]
#  [6 4 3]
#  [2 7 5]]
#
# [[8 3 0]
#  [6 1 4]
#  [2 7 5]]
#
# [[0 8 3]
#  [6 1 4]
#  [2 7 5]]
#
# [[1 6 3]
#  [8 0 4]
#  [2 7 5]]
#
# [[1 3 0]
#  [8 6 4]
#  [2 7 5]]
#
# [[8 1 3]
#  [2 5 6]
#  [7 4 0]]
#
# [[8 1 0]
#  [2 5 3]
#  [7 4 6]]
#
# [[8 3 0]
#  [2 1 5]
#  [7 4 6]]
#
# [[0 8 3]
#  [2 1 5]
#  [7 4 6]]
#
# [[8 1 3]
#  [4 0 5]
#  [2 7 6]]
#
# [[0 1 3]
#  [8 4 5]
#  [2 7 6]]
#
# [[8 4 1]
#  [2 6 3]
#  [7 5 0]]
#
# [[8 4 1]
#  [2 6 3]
#  [0 7 5]]
#
# [[8 4 1]
#  [2 3 5]
#  [7 6 0]]
#
# [[8 4 0]
#  [2 3 1]
#  [7 6 5]]
#
# [[8 4 1]
#  [7 2 3]
#  [0 6 5]]
#
# [[0 4 1]
#  [8 2 3]
#  [7 6 5]]

# %%
puzzle = Puzzle(initialGrid,initialIndex,finalGrid,finalIndex)
puzzle.solve()
puzzle.print()
print("The MINIMUM number of steps to reach the final state is :- ",minimumSteps)
# Out:
# Initial State:-
#  [[1 2 3]
#  [8 0 4]
#  [7 6 5]]
#
# Final State:-
#  [[2 8 1]
#  [0 4 3]
#  [7 6 5]]
#
#
# States Explored:  358
#
# Solution:-
#
# Move:-  UP
#  [[1 0 3]
#  [8 2 4]
#  [7 6 5]]
#
# Move:-  DOWN
#  [[0 1 3]
#  [8 2 4]
#  [7 6 5]]
#
# Move:-  RIGHT
#  [[8 1 3]
#  [0 2 4]
#  [7 6 5]]
#
# Move:-  LEFT
#  [[8 1 3]
#  [2 0 4]
#  [7 6 5]]
#
# Move:-  DOWN
#  [[8 1 3]
#  [2 4 0]
#  [7 6 5]]
#
# Move:-  LEFT
#  [[8 1 0]
#  [2 4 3]
#  [7 6 5]]
#
# Move:-  UP
#  [[8 0 1]
#  [2 4 3]
#  [7 6 5]]
#
# Move:-  RIGHT
#  [[0 8 1]
#  [2 4 3]
#  [7 6 5]]
#
# Move:-  LEFT
#  [[2 8 1]
#  [0 4 3]
#  [7 6 5]]
#
# The Final State is Reached!
# The MINIMUM number of steps to reach the final state is :-  9
